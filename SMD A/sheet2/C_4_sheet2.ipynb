# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.optimize import fmin
from uncertainties import ufloat
import uncertainties as unp
import scipy as si
from scipy.integrate import quad
def anpassen(x):
      return abs(integrate.quad(func_g,0,x)[0]-1/2)

def maximumfinden(funktion,guess):
   return fmin(-abs(funktion),guess)

def func_g(x):
   return np.sqrt(2/np.pi)*x**2*np.exp((-x**2)/2*a**2)/a**3


a = 2

print(fmin(anpassen,fmin(anpassen,5.1)))
xplot = np.linspace(0,4,100)
yplot = -func_g(xplot)

plt.plot(xplot,yplot)
plt.grid()
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.484375
#          Iterations: 13
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.484375
#          Iterations: 13
#          Function evaluations: 38
# [5.1]

# %%
from scipy.integrate import quad

def integrand(x, a, b):

    return a*x**2 + b


a = 2
b = 1
I = quad(integrand, 0, 1, args=(a,b))
I
# Out:
# (1.6666666666666667, 1.8503717077085944e-14)
