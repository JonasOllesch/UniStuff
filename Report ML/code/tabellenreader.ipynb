# %%
import pandas as pd
from IPython.display import display

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv('sorted_results_optimisation_128_without_basemodel.csv')

# Display the entire DataFrame
display(df)
# Out:
#     num_conv_layers  max_filters  dropout  dense_nodes  \
# 0                 3           64      0.5          128
# 1                 3           64      0.5          512
# 2                 3           32      0.4          128
# 3                 3           64      0.5          256
# 4                 3           64      0.4          256
# 5                 3           32      0.4          256
# 6                 3          128      0.5          256
# 7                 3           32      0.5          128
# 8                 3          128      0.5          512
# 9                 3           32      0.5          128
# 10                3           32      0.4          512
# 11                3          128      0.5          128
# 12                3           64      0.4          128
# 13                3          128      0.4          256
# 14                3           64      0.5          256
# 15                3          128      0.4          512
# 16                2           64      0.4          128
# 17                2           64      0.5          128
# 18                3           64      0.4          512
# 19                2           32      0.5          128
# 20                2          128      0.5          128
# 21                3           64      0.4          512
# 22                3          128      0.4          128
# 23                2           32      0.5          128
# 24                3           32      0.5          256
# 25                2          128      0.4          512
# 26                3          128      0.5          256
# 27                3           64      0.5          512
# 28                3           32      0.5          256
# 29                3           32      0.5          512
# 30                2          128      0.4          256
# 31                2           32      0.5          256
# 32                2           32      0.5          512
# 33                3           32      0.5          512
# 34                3           64      0.4          128
# 35                3          128      0.4          512
# 36                2           32      0.4          128
# 37                3           64      0.5          128
# 38                3           32      0.4          256
# 39                3           32      0.4          512
# 40                2           64      0.4          256
# 41                2           64      0.4          256
# 42                2          128      0.5          256
# 43                2           64      0.5          256
# 44                2           64      0.4          512
# 45                2           64      0.5          512
# 46                2           32      0.4          256
# 47                2           32      0.4          512
# 48                3          128      0.5          512
# 49                2           32      0.4          512
# 50                2           64      0.4          512
# 51                2           64      0.4          128
# 52                2           64      0.5          128
# 53                2           64      0.5          256
# 54                2           32      0.4          256
# 55                2           32      0.4          128
# 56                2           32      0.5          512
# 57                2          128      0.4          256
# 58                3          128      0.4          256
# 59                2           32      0.5          256
# 60                2          128      0.5          512
# 61                2          128      0.5          256
# 62                3          128      0.5          128
# 63                2          128      0.5          512
# 64                2          128      0.5          128
# 65                3           32      0.4          128
# 66                3           64      0.4          256
# 67                2          128      0.4          512
# 68                3          128      0.4          128
# 69                2          128      0.4          128
# 70                2          128      0.4          128
# 71                2           64      0.5          512
#
#    activation_function_conv  status  best_val_acc_train_acc  best_val_acc  \
# 0                      relu  loaded                0.950067       0.94170
# 1                      relu  loaded                0.943667       0.93470
# 2                      relu  loaded                0.945200       0.93450
# 3                      relu  loaded                0.934067       0.93260
# 4                      relu  loaded                0.948133       0.93255
# 5                      relu  loaded                0.939467       0.93235
# 6                      relu  loaded                0.942233       0.93210
# 7                      relu  loaded                0.944000       0.93205
# 8                      relu  loaded                0.940367       0.93100
# 9                 LeakyReLU  loaded                0.939433       0.93100
# 10                     relu  loaded                0.936833       0.93065
# 11                     relu  loaded                0.928900       0.92880
# 12                     relu  loaded                0.914400       0.92720
# 13                     relu  loaded                0.920400       0.92710
# 14                LeakyReLU  loaded                0.921100       0.92670
# 15                     relu  loaded                0.945933       0.92540
# 16                     relu  loaded                0.938733       0.92340
# 17                     relu  loaded                0.940400       0.92290
# 18                     relu  loaded                0.937533       0.92155
# 19                     relu  loaded                0.924900       0.92050
# 20                     relu  loaded                0.917967       0.92050
# 21                LeakyReLU  loaded                0.937400       0.91865
# 22                     relu  loaded                0.940633       0.91830
# 23                LeakyReLU  loaded                0.926267       0.91730
# 24                LeakyReLU  loaded                0.942433       0.91695
# 25                     relu  loaded                0.921467       0.91565
# 26                LeakyReLU  loaded                0.937833       0.91550
# 27                LeakyReLU  loaded                0.937333       0.91545
# 28                     relu  loaded                0.928767       0.91040
# 29                     relu  loaded                0.913233       0.90800
# 30                     relu  loaded                0.917367       0.90785
# 31                     relu  loaded                0.905233       0.90630
# 32                     relu  loaded                0.925767       0.90600
# 33                LeakyReLU  loaded                0.933000       0.90525
# 34                LeakyReLU  loaded                0.930533       0.90510
# 35                LeakyReLU  loaded                0.899267       0.89950
# 36                     relu  loaded                0.930433       0.89930
# 37                LeakyReLU  loaded                0.902133       0.89615
# 38                LeakyReLU  loaded                0.903067       0.89500
# 39                LeakyReLU  loaded                0.916000       0.89315
# 40                LeakyReLU  loaded                0.905433       0.89290
# 41                     relu  loaded                0.924500       0.89270
# 42                LeakyReLU  loaded                0.905533       0.89190
# 43                LeakyReLU  loaded                0.904700       0.89150
# 44                     relu  loaded                0.903600       0.89115
# 45                LeakyReLU  loaded                0.907967       0.89050
# 46                     relu  loaded                0.907833       0.88785
# 47                     relu  loaded                0.889167       0.88745
# 48                LeakyReLU  loaded                0.897267       0.88555
# 49                LeakyReLU  loaded                0.898667       0.88545
# 50                LeakyReLU  loaded                0.881700       0.88005
# 51                LeakyReLU  loaded                0.871367       0.87935
# 52                LeakyReLU  loaded                0.873533       0.87585
# 53                     relu  loaded                0.874667       0.87520
# 54                LeakyReLU  loaded                0.878833       0.87450
# 55                LeakyReLU  loaded                0.888800       0.87435
# 56                LeakyReLU  loaded                0.908500       0.87345
# 57                LeakyReLU  loaded                0.869767       0.87305
# 58                LeakyReLU  loaded                0.899967       0.87140
# 59                LeakyReLU  loaded                0.877467       0.87075
# 60                LeakyReLU  loaded                0.891867       0.87020
# 61                     relu  loaded                0.911100       0.86960
# 62                LeakyReLU  loaded                0.891167       0.86705
# 63                     relu  loaded                0.902967       0.86615
# 64                LeakyReLU  loaded                0.893200       0.86590
# 65                LeakyReLU  loaded                0.900200       0.86550
# 66                LeakyReLU  loaded                0.903367       0.86200
# 67                LeakyReLU  loaded                0.897500       0.86115
# 68                LeakyReLU  loaded                0.848367       0.85035
# 69                LeakyReLU  loaded                0.824467       0.84380
# 70                     relu  loaded                0.886133       0.84340
# 71                     relu  loaded                0.883300       0.83445
#
#     best_val_acc_train_loss  best_val_acc_loss  best_val_epoch
# 0                  0.148508           0.187000              14
# 1                  0.146905           0.170992              10
# 2                  0.144197           0.176641               4
# 3                  0.180251           0.190638               8
# 4                  0.166233           0.231369              15
# 5                  0.152721           0.172946               9
# 6                  0.170646           0.220632              15
# 7                  0.152347           0.175270              11
# 8                  0.188370           0.220867              15
# 9                  0.162308           0.175924              14
# 10                 0.159870           0.176201               7
# 11                 0.178456           0.182870               9
# 12                 0.216042           0.186162               7
# 13                 0.223021           0.219522              11
# 14                 0.222258           0.201575              11
# 15                 0.199187           0.288786              18
# 16                 0.157990           0.184449              14
# 17                 0.153798           0.189653              16
# 18                 0.162213           0.197056               6
# 19                 0.200393           0.219003              11
# 20                 0.221557           0.217483               9
# 21                 0.165876           0.208429              13
# 22                 0.159036           0.212147               9
# 23                 0.200887           0.226017              23
# 24                 0.152053           0.214886              17
# 25                 0.261828           0.273544              15
# 26                 0.160227           0.215037              15
# 27                 0.159749           0.209248              13
# 28                 0.183760           0.241992               4
# 29                 0.232025           0.256886               6
# 30                 0.230884           0.259817              20
# 31                 0.236600           0.227901               8
# 32                 0.221537           0.286356              14
# 33                 0.187062           0.259818              10
# 34                 0.193842           0.268894               6
# 35                 0.256328           0.254124               1
# 36                 0.212346           0.311087              21
# 37                 0.250414           0.256164               4
# 38                 0.249017           0.261305               0
# 39                 0.217265           0.255055               0
# 40                 0.266560           0.305179               6
# 41                 0.211447           0.287787              15
# 42                 0.241211           0.269318              10
# 43                 0.303961           0.310699               7
# 44                 0.259202           0.306450              10
# 45                 0.247743           0.296485              11
# 46                 0.273183           0.351362              10
# 47                 0.299260           0.308847               3
# 48                 0.294729           0.365500               3
# 49                 0.273063           0.328263              11
# 50                 0.336769           0.333067               1
# 51                 0.319203           0.304606               8
# 52                 0.298197           0.307911               2
# 53                 0.321873           0.320646               1
# 54                 0.325674           0.348614              11
# 55                 0.316895           0.392252               8
# 56                 0.310540           0.454997              14
# 57                 0.341288           0.321202               2
# 58                 0.323828           0.344469               0
# 59                 0.305836           0.318228               2
# 60                 0.278374           0.305563               2
# 61                 0.256033           0.385101              12
# 62                 0.321061           0.391963               1
# 63                 0.351797           0.504519              13
# 64                 0.326985           0.399706               9
# 65                 0.313734           0.449281               4
# 66                 0.288307           0.424305               3
# 67                 0.442080           0.660537              19
# 68                 0.381252           0.367473               0
# 69                 0.475412           0.444433               4
# 70                 0.409844           0.575517              13
# 71                 0.407737           0.582233               8
